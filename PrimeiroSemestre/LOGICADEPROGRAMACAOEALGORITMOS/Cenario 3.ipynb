# %%
Morador=input('Voce mora em Guaxupe?')
if Morador=='sim':
  idade=int(input('Quantos anos voce tem?'))
  if idade>18:
    print('Feliz morador de Guaxupe com mais de 18 anos')
else:
  print('Que pena, Guaxupe eh uma cidade linda!!')
print('Fim')
# Out:
# Voce mora em Guaxupe?sim
# Quantos anos voce tem?17
# Fim
