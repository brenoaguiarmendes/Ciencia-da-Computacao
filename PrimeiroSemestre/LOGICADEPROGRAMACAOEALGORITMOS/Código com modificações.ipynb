# %%
c = 0
quantidade = 1
while quantidade<100:
  if quantidade == 0:
    print ('sem embalagem')
    break
  else:
    quantidade= int(input('informe a quantidade'))
else:
  while quantidade >= 10:
    quantidade= quantidade - 10
    c= c+1
  print("pacotes criados:{}, sobraram:{}".format(c,quantidade))
# Out:
# informe a quantidade100
# pacotes criados:10, sobraram:0
