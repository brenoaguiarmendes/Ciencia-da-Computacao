# %%
Morador=input('Voce mora em Guaxupe?')
if Morador=='sim':
  idade=int(input('Quantos anos voce tem?'))
  if idade>18:
    print('Feliz morador de Guaxupe com mais de 18 anos')
  else:
    print('mais um infante morador de Guaxupe')
else:
  interesse=str(input('Voce mudaria para Guaxupe?'))
  if interesse=='sim':
    print('Que bom,sera muito bem vindo a Guaxupe')
  else:
    print('Ok, tambem fico feliz em saber que es feliz onde mora')
# Out:
# Voce mora em Guaxupe?nao
# Voce mudaria para Guaxupe?nao
# Ok, tambem fico feliz em saber que es feliz onde mora
