# %%
while True:
  quantidade =int(input('informe a qnt'))
  if quantidade == 0:
    print ('fim sem embalar')
    break
  elif quantidade > 100:
    while True:
      quantidade = quantidade - 10
      if quantidade < 10:
        quantidade = 0
        print ('pacotes criados')
        break
    break
